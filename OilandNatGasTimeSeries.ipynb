# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading the Time Series file with Date mapped to the day's Crude Oil and Natural Gas Prices

# %%
datadf = pd.read_excel("D:\\Minor Project\\CrudeOil&NaturalGas\\CrudeOil_NatGas_Prices.xlsx")

# %% [markdown]
# The Dataset contains 10 years' Crude Oil and Natural Gas Price data , starting from 21st December 2015

# %%
datadf
# Out:
#            Date  CrudeOilValue  HenryHubNaturalGas
# 0    2015-12-21          34.55                1.76
# 1    2015-12-22          36.12                1.73
# 2    2015-12-23          36.76                1.63
# 3    2015-12-24          37.62                1.63
# 4    2015-12-28          36.36                2.11
# ...         ...            ...                 ...
# 2551 2025-12-15          56.97                3.90
# 2552 2025-12-16          55.17                3.58
# 2553 2025-12-17          56.90                3.66
# 2554 2025-12-18          55.90                 NaN
# 2555 2025-12-19          56.54                 NaN
#
# [2556 rows x 3 columns]

# %% [markdown]
# The Date column is in Datetime format

# %%
datadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2556 entries, 0 to 2555
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                2556 non-null   datetime64[ns]
#  1   CrudeOilValue       2556 non-null   float64
#  2   HenryHubNaturalGas  2502 non-null   float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 60.0 KB

# %% [markdown]
# Indexing the Date Column

# %%
datadf = datadf.set_index('Date')
print(datadf.head(5))
# Out:
#             CrudeOilValue  HenryHubNaturalGas
# Date
# 2015-12-21          34.55                1.76
# 2015-12-22          36.12                1.73
# 2015-12-23          36.76                1.63
# 2015-12-24          37.62                1.63
# 2015-12-28          36.36                2.11

# %% [markdown]
# Plotting the graph for crude oil prices

# %%
plt.plot(datadf.index, datadf['CrudeOilValue'])

# %% [markdown]
# Plotting the graph for Natural Gas Prices, according to Henry Hub Pipeline

# %%
plt.plot(datadf.index, datadf['HenryHubNaturalGas'])
